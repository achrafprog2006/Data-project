# %% [markdown]
# # < Analyzing Club Activity and Performance >

# %% [markdown]
# ### Step 1 : Importing necessary libraries

# %%
# importing the  Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2 : Load the dataset
#
#  Read the CSV file(AppsClub_events_data.csv) into a DataFrame & setting "Session ID" colomn as index colomn

# %%
filename ="AppsClub_events_data.csv"
df = pd.read_csv(filename)

df=df.set_index("Session ID")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 1 to 46
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Event Name       46 non-null     object
#  1   Date             46 non-null     object
#  2   Attendees Count  45 non-null     float64
#  3   Rating           43 non-null     float64
#  4   Speaker          46 non-null     object
#  5   New Attendees    46 non-null     int64
#  6   Online/Offline   43 non-null     object
#  7   Duration         46 non-null     int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.2+ KB

# %% [markdown]
# #  Step 3: Handling missing values

# %% [markdown]
# check for nan values :

# %%
#check nan values
print(df.isna().any())
#there is nan values in Rating,AttendeesCount and Online/Offline colomns
# Out:
# Event Name         False
# Date               False
# Attendees Count     True
# Rating              True
# Speaker            False
# New Attendees      False
# Online/Offline      True
# Duration           False
# dtype: bool

# %% [raw]
# Filling missing values with the average for "Rating & AttendeesCount" colomns and the most frequent value for "Online/Offline" colomn :

# %%
#fill nan in in Online/Offline colomn by most frequent element :
most_frequent_element=df["Online/Offline"].value_counts().idxmax()
df["Online/Offline"]=df["Online/Offline"].fillna(most_frequent_element)

#fill nan in in Rating colomn by average :
df["Rating"]=df["Rating"].fillna(df["Rating"].mean())

#fill nan in AttendeesCount colomn by average :
df["Attendees Count"]=df["Attendees Count"].fillna(df["Attendees Count"].mean())

#check nan values
print(df.isna().any())
# Out:
# Event Name         False
# Date               False
# Attendees Count    False
# Rating             False
# Speaker            False
# New Attendees      False
# Online/Offline     False
# Duration           False
# dtype: bool

# %% [markdown]
# ok , there is not Nan values now

# %% [markdown]
# ### Step 4: Event Analysis
# Calculate the average number of attendees for each event :

# %%
df_by_eventname=df.groupby("Event Name")
df_by_eventname["Attendees Count"].mean()
# Out:
# Event Name
# AppsChill                      25.000000
# Biweekly Contest               20.000000
# CP Bootcamp                    57.500000
# Conference                    150.000000
# Cyber Security Foundations     31.166667
# Intro to CS                    50.181818
# Intro to Data                  26.250000
# Java                           20.000000
# Let's Talk                     80.000000
# Meet Our Laureat               70.000000
# PFA-PFE                       100.000000
# Python Basics                  34.879012
# Visite Code 212                70.000000
# Name: Attendees Count, dtype: float64

# %% [markdown]
# Calculating the average rating for each event :

# %%
df_by_eventname["Rating"].mean()
# Out:
# Event Name
# AppsChill                     4.500000
# Biweekly Contest              4.300000
# CP Bootcamp                   4.700000
# Conference                    5.000000
# Cyber Security Foundations    4.358527
# Intro to CS                   4.184144
# Intro to Data                 3.950000
# Java                          4.133333
# Let's Talk                    5.000000
# Meet Our Laureat              4.900000
# PFA-PFE                       4.900000
# Python Basics                 4.377778
# Visite Code 212               4.000000
# Name: Rating, dtype: float64

# %% [raw]
# Calculating the average number of attendees for online vs offline events :

# %%
df.groupby(["Online/Offline"])["Attendees Count"].mean()
# Out:
# Online/Offline
# Offline    46.368889
# Online     27.727273
# Name: Attendees Count, dtype: float64

# %% [raw]
#  Calculating the average rating for online vs. offline events :

# %%
df.groupby(["Online/Offline"])["Rating"].mean()
# Out:
# Online/Offline
# Offline    4.275017
# Online     4.486469
# Name: Rating, dtype: float64

# %% [markdown]
#  ### Step 5: Identify the most and least popular events

# %% [markdown]
#  Rank all events by attendance count in descending order :

# %%
events_attendance=df.sort_values(["Attendees Count"],ascending=False)
events_attendance
# Out:
#                             Event Name         Date  Attendees Count  \
# Session ID
# 46                          Conference   9-Nov-2024       150.000000
# 45                             PFA-PFE   5-Nov-2024       100.000000
# 44                          Let's Talk  12-Jan-2025        80.000000
# 12                       Python Basics   8-Oct-2024        80.000000
# 42                    Meet Our Laureat   5-Oct-2024        70.000000
# 39                     Visite Code 212  21-Oct-2024        70.000000
# 14                       Python Basics  15-Oct-2024        65.000000
# 40                         CP Bootcamp  24-Nov-2024        60.000000
# 41                         CP Bootcamp  16-Jan-2025        55.000000
# 2                          Intro to CS  14-Oct-2024        52.000000
# 4                          Intro to CS  28-Oct-2024        51.000000
# 7                          Intro to CS  18-Nov-2024        51.000000
# 16                       Python Basics  22-Oct-2024        50.000000
# 1                          Intro to CS   7-Oct-2024        50.000000
# 9                          Intro to CS   2-Dec-2024        50.000000
# 5                          Intro to CS   4-Nov-2024        50.000000
# 6                          Intro to CS  11-Nov-2024        50.000000
# 8                          Intro to CS  25-Nov-2024        50.000000
# 11                         Intro to CS  16-Dec-2024        50.000000
# 10                         Intro to CS   9-Dec-2024        49.000000
# 3                          Intro to CS  21-Oct-2024        49.000000
# 20                       Python Basics   5-Nov-2024        41.911111
# 21                       Intro to Data  12-Nov-2024        40.000000
# 34          Cyber Security Foundations  14-Nov-2024        36.000000
# 18                       Python Basics  29-Oct-2024        35.000000
# 33          Cyber Security Foundations   7-Nov-2024        35.000000
# 35          Cyber Security Foundations  21-Nov-2024        33.000000
# 22                       Intro to Data  19-Nov-2024        30.000000
# 36          Cyber Security Foundations  28-Nov-2024        30.000000
# 37          Cyber Security Foundations   5-Dec-2024        28.000000
# 25                                Java  10-Dec-2024        25.000000
# 38          Cyber Security Foundations  12-Dec-2024        25.000000
# 43                           AppsChill  15-Nov-2024        25.000000
# 31                    Biweekly Contest  23-Nov-2024        20.000000
# 32                    Biweekly Contest   7-Dec-2024        20.000000
# 30                    Biweekly Contest   9-Nov-2024        20.000000
# 29                    Biweekly Contest  26-Oct-2024        20.000000
# 26                                Java  17-Dec-2024        20.000000
# 23                       Intro to Data  26-Nov-2024        20.000000
# 28                    Biweekly Contest  12-Oct-2024        20.000000
# 24                       Intro to Data   3-Dec-2024        15.000000
# 27                                Java  24-Dec-2024        15.000000
# 19                       Python Basics   2-Nov-2024        14.000000
# 15                       Python Basics  19-Oct-2024        11.000000
# 13                       Python Basics  12-Oct-2024        10.000000
# 17                       Python Basics  26-Oct-2024         7.000000
#
#               Rating              Speaker  New Attendees Online/Offline  \
# Session ID
# 46          5.000000  Youssef Taguejgalet             50        Offline
# 45          4.900000          Ilyas Nmili             22        Offline
# 44          5.000000          Ilyas Nmili             35         Online
# 12          4.600000      Amine Ait Hamma             20        Offline
# 42          4.900000          Ilyas Nmili             30         Online
# 39          4.000000          Ilyas Nmili             20        Offline
# 14          4.500000      Amine Ait Hamma             15        Offline
# 40          4.700000      Amine Ait Hamma             25        Offline
# 41          4.700000  Youssef Taguejgalet             20        Offline
# 2           4.500000      Hasnae Amarmach              8        Offline
# 4           4.300000      Hasnae Amarmach              9        Offline
# 7           4.300000      Hasnae Amarmach              4        Offline
# 16          4.100000      Amine Ait Hamma             10        Offline
# 1           4.200000          Ilyas Nmili             10        Offline
# 9           4.200000          Ilyas Nmili              2        Offline
# 5           4.325581      Hasnae Amarmach              6        Offline
# 6           4.000000      Hasnae Amarmach              5        Offline
# 8           4.100000      Hasnae Amarmach              3        Offline
# 11          4.100000      Hasnae Amarmach              1        Offline
# 10          4.000000      Hasnae Amarmach              2        Offline
# 3           4.000000      Hasnae Amarmach              7        Offline
# 20          4.000000      Amine Ait Hamma              2        Offline
# 21          4.400000   Nohaila El Idrissi             15        Offline
# 34          4.500000       Broad Sec Cell             12        Offline
# 18          3.800000      Amine Ait Hamma              5        Offline
# 33          4.700000       Broad Sec Cell             15        Offline
# 35          4.300000       Broad Sec Cell             10        Offline
# 22          3.500000   Nohaila El Idrissi             10        Offline
# 36          4.000000       Broad Sec Cell              8        Offline
# 37          4.325581       Broad Sec Cell              5         Online
# 25          4.500000      Amine Ait Hamma             10        Offline
# 38          4.325581       Broad Sec Cell              3         Online
# 43          4.500000  Youssef Taguejgalet             10         Online
# 31          4.300000          Ilyas Nmili              4        Offline
# 32          4.900000      Amine Ait Hamma              3        Offline
# 30          4.100000  Youssef Taguejgalet              3        Offline
# 29          4.200000      Amine Ait Hamma              4        Offline
# 26          4.000000      Amine Ait Hamma              5         Online
# 23          4.000000   Nohaila El Idrissi              5        Offline
# 28          4.000000          Ilyas Nmili              5        Offline
# 24          3.900000   Nohaila El Idrissi              3        Offline
# 27          3.900000      Amine Ait Hamma              2         Online
# 19          4.600000      Amine Ait Hamma              4         Online
# 15          4.600000      Amine Ait Hamma              1         Online
# 13          4.600000      Amine Ait Hamma              5         Online
# 17          4.600000      Amine Ait Hamma              0         Online
#
#             Duration
# Session ID
# 46               240
# 45               120
# 44                60
# 12                90
# 42               148
# 39               180
# 14                90
# 40               180
# 41               180
# 2                 75
# 4                 90
# 7                 90
# 16                90
# 1                 60
# 9                 90
# 5                 80
# 6                 90
# 8                 90
# 11                90
# 10                90
# 3                 90
# 20                90
# 21                80
# 34                90
# 18                90
# 33                70
# 35                90
# 22                70
# 36                75
# 37                90
# 25                80
# 38                80
# 43               120
# 31               180
# 32               180
# 30               180
# 29               180
# 26               120
# 23                90
# 28               180
# 24                90
# 27               100
# 19               120
# 15               120
# 13               120
# 17               120

# %% [markdown]
#  Retrieving the top 5 most attended events:

# %%
events_attendance.iloc[:5]
# Out:
#                   Event Name         Date  Attendees Count  Rating  \
# Session ID
# 46                Conference   9-Nov-2024            150.0     5.0
# 45                   PFA-PFE   5-Nov-2024            100.0     4.9
# 44                Let's Talk  12-Jan-2025             80.0     5.0
# 12             Python Basics   8-Oct-2024             80.0     4.6
# 42          Meet Our Laureat   5-Oct-2024             70.0     4.9
#
#                         Speaker  New Attendees Online/Offline  Duration
# Session ID
# 46          Youssef Taguejgalet             50        Offline       240
# 45                  Ilyas Nmili             22        Offline       120
# 44                  Ilyas Nmili             35         Online        60
# 12              Amine Ait Hamma             20        Offline        90
# 42                  Ilyas Nmili             30         Online       148

# %% [markdown]
# Retrieving the bottom 5 least attended events

# %%
events_attendance.iloc[-5:]
# Out:
#                Event Name         Date  Attendees Count  Rating  \
# Session ID
# 27                   Java  24-Dec-2024             15.0     3.9
# 19          Python Basics   2-Nov-2024             14.0     4.6
# 15          Python Basics  19-Oct-2024             11.0     4.6
# 13          Python Basics  12-Oct-2024             10.0     4.6
# 17          Python Basics  26-Oct-2024              7.0     4.6
#
#                     Speaker  New Attendees Online/Offline  Duration
# Session ID
# 27          Amine Ait Hamma              2         Online       100
# 19          Amine Ait Hamma              4         Online       120
# 15          Amine Ait Hamma              1         Online       120
# 13          Amine Ait Hamma              5         Online       120
# 17          Amine Ait Hamma              0         Online       120

# %% [markdown]
# A bar chart presenting all events by attendance count:

# %%
events_attendance.plot(y="Attendees Count" ,kind="bar")
# Out:
# <Axes: xlabel='Session ID'>

# %% [markdown]
# ###  Step 6: Analyze event duration vs feedback score

# %% [markdown]
#  Plotting a scatter plot representing the relationship between duration and feedback score(Rating):

# %%
df.plot(kind="scatter" ,x="Duration" ,y="Rating")
# Out:
# <Axes: xlabel='Duration', ylabel='Rating'>

# %% [markdown]
# ###  Step 7: Count events organized by each member

# %% [markdown]
#  Count occurrences of each speaker

# %%
df["Speaker"].value_counts()
# Out:
# Speaker
# Amine Ait Hamma        15
# Hasnae Amarmach         9
# Ilyas Nmili             8
# Broad Sec Cell          6
# Nohaila El Idrissi      4
# Youssef Taguejgalet     4
# Name: count, dtype: int64

# %% [markdown]
# ###  Step 8: Identify the most active member

# %% [markdown]
# the maximum number of events :

# %%
df["Event Name"].value_counts().idxmax()
# Out:
# 'Intro to CS'

# %% [markdown]
# the speaker with the highest count :

# %%
df["Speaker"].value_counts().idxmax()
# Out:
# 'Amine Ait Hamma'

# %% [markdown]
#  ### Step 9: Best-rated organizing member

# %% [markdown]
#  the average rating per speaker :

# %%
df.groupby("Speaker")["Rating"].mean()
# Out:
# Speaker
# Amine Ait Hamma        4.373333
# Broad Sec Cell         4.358527
# Hasnae Amarmach        4.180620
# Ilyas Nmili            4.437500
# Nohaila El Idrissi     3.950000
# Youssef Taguejgalet    4.575000
# Name: Rating, dtype: float64

# %% [markdown]
#  the highest rating :

# %%
df["Rating"].max()
# Out:
# 5.0

# %% [markdown]
#  ### Step 10 :Visualizing new attendee trend overtime

# %% [markdown]
#  Sort the dataset by date :

# %%
#the type of the colomn "Date" is Object , we want to convert it into datetime , to have the data sorted well by date 
df["Date"] = pd.to_datetime(df["Date"])
#sort by date
df=df.sort_values("Date")
df
# Out:
#                             Event Name       Date  Attendees Count    Rating  \
# Session ID
# 42                    Meet Our Laureat 2024-10-05        70.000000  4.900000
# 1                          Intro to CS 2024-10-07        50.000000  4.200000
# 12                       Python Basics 2024-10-08        80.000000  4.600000
# 28                    Biweekly Contest 2024-10-12        20.000000  4.000000
# 13                       Python Basics 2024-10-12        10.000000  4.600000
# 2                          Intro to CS 2024-10-14        52.000000  4.500000
# 14                       Python Basics 2024-10-15        65.000000  4.500000
# 15                       Python Basics 2024-10-19        11.000000  4.600000
# 3                          Intro to CS 2024-10-21        49.000000  4.000000
# 39                     Visite Code 212 2024-10-21        70.000000  4.000000
# 16                       Python Basics 2024-10-22        50.000000  4.100000
# 17                       Python Basics 2024-10-26         7.000000  4.600000
# 29                    Biweekly Contest 2024-10-26        20.000000  4.200000
# 4                          Intro to CS 2024-10-28        51.000000  4.300000
# 18                       Python Basics 2024-10-29        35.000000  3.800000
# 19                       Python Basics 2024-11-02        14.000000  4.600000
# 5                          Intro to CS 2024-11-04        50.000000  4.325581
# 20                       Python Basics 2024-11-05        41.911111  4.000000
# 45                             PFA-PFE 2024-11-05       100.000000  4.900000
# 33          Cyber Security Foundations 2024-11-07        35.000000  4.700000
# 30                    Biweekly Contest 2024-11-09        20.000000  4.100000
# 46                          Conference 2024-11-09       150.000000  5.000000
# 6                          Intro to CS 2024-11-11        50.000000  4.000000
# 21                       Intro to Data 2024-11-12        40.000000  4.400000
# 34          Cyber Security Foundations 2024-11-14        36.000000  4.500000
# 43                           AppsChill 2024-11-15        25.000000  4.500000
# 7                          Intro to CS 2024-11-18        51.000000  4.300000
# 22                       Intro to Data 2024-11-19        30.000000  3.500000
# 35          Cyber Security Foundations 2024-11-21        33.000000  4.300000
# 31                    Biweekly Contest 2024-11-23        20.000000  4.300000
# 40                         CP Bootcamp 2024-11-24        60.000000  4.700000
# 8                          Intro to CS 2024-11-25        50.000000  4.100000
# 23                       Intro to Data 2024-11-26        20.000000  4.000000
# 36          Cyber Security Foundations 2024-11-28        30.000000  4.000000
# 9                          Intro to CS 2024-12-02        50.000000  4.200000
# 24                       Intro to Data 2024-12-03        15.000000  3.900000
# 37          Cyber Security Foundations 2024-12-05        28.000000  4.325581
# 32                    Biweekly Contest 2024-12-07        20.000000  4.900000
# 10                         Intro to CS 2024-12-09        49.000000  4.000000
# 25                                Java 2024-12-10        25.000000  4.500000
# 38          Cyber Security Foundations 2024-12-12        25.000000  4.325581
# 11                         Intro to CS 2024-12-16        50.000000  4.100000
# 26                                Java 2024-12-17        20.000000  4.000000
# 27                                Java 2024-12-24        15.000000  3.900000
# 44                          Let's Talk 2025-01-12        80.000000  5.000000
# 41                         CP Bootcamp 2025-01-16        55.000000  4.700000
#
#                         Speaker  New Attendees Online/Offline  Duration
# Session ID
# 42                  Ilyas Nmili             30         Online       148
# 1                   Ilyas Nmili             10        Offline        60
# 12              Amine Ait Hamma             20        Offline        90
# 28                  Ilyas Nmili              5        Offline       180
# 13              Amine Ait Hamma              5         Online       120
# 2               Hasnae Amarmach              8        Offline        75
# 14              Amine Ait Hamma             15        Offline        90
# 15              Amine Ait Hamma              1         Online       120
# 3               Hasnae Amarmach              7        Offline        90
# 39                  Ilyas Nmili             20        Offline       180
# 16              Amine Ait Hamma             10        Offline        90
# 17              Amine Ait Hamma              0         Online       120
# 29              Amine Ait Hamma              4        Offline       180
# 4               Hasnae Amarmach              9        Offline        90
# 18              Amine Ait Hamma              5        Offline        90
# 19              Amine Ait Hamma              4         Online       120
# 5               Hasnae Amarmach              6        Offline        80
# 20              Amine Ait Hamma              2        Offline        90
# 45                  Ilyas Nmili             22        Offline       120
# 33               Broad Sec Cell             15        Offline        70
# 30          Youssef Taguejgalet              3        Offline       180
# 46          Youssef Taguejgalet             50        Offline       240
# 6               Hasnae Amarmach              5        Offline        90
# 21           Nohaila El Idrissi             15        Offline        80
# 34               Broad Sec Cell             12        Offline        90
# 43          Youssef Taguejgalet             10         Online       120
# 7               Hasnae Amarmach              4        Offline        90
# 22           Nohaila El Idrissi             10        Offline        70
# 35               Broad Sec Cell             10        Offline        90
# 31                  Ilyas Nmili              4        Offline       180
# 40              Amine Ait Hamma             25        Offline       180
# 8               Hasnae Amarmach              3        Offline        90
# 23           Nohaila El Idrissi              5        Offline        90
# 36               Broad Sec Cell              8        Offline        75
# 9                   Ilyas Nmili              2        Offline        90
# 24           Nohaila El Idrissi              3        Offline        90
# 37               Broad Sec Cell              5         Online        90
# 32              Amine Ait Hamma              3        Offline       180
# 10              Hasnae Amarmach              2        Offline        90
# 25              Amine Ait Hamma             10        Offline        80
# 38               Broad Sec Cell              3         Online        80
# 11              Hasnae Amarmach              1        Offline        90
# 26              Amine Ait Hamma              5         Online       120
# 27              Amine Ait Hamma              2         Online       100
# 44                  Ilyas Nmili             35         Online        60
# 41          Youssef Taguejgalet             20        Offline       180

# %% [markdown]
# A plot to show how new attendees changed overtime:

# %%
df.plot(x="Date" ,y="New Attendees")
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Mr Achraf Boulhem
